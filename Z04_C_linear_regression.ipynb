# %% [markdown]
# # Regresja liniowa
#
# Naszym Celem jest empityczne sprawdzenie twierdzenia:
#
# Niech $A \in \mathbb{R}^{N\times K}$ będzie macierzą która przekształca $\mathbb{R}^{K}$ w $\mathbb{R}^N$, i niech $y \in \mathbb{R}^{K}$.
#
# Wtedy punkt $x_0 \in \mathbb{R}^K$ spełnia
#
# $$
# x_0 = \mathrm{argmin} \{ x \in \mathbb{R}^K   \colon \| Ax - y \|^2 \}
# $$
#
# wtedy i tylko wtedy gdy
#
# $$
# A^TA x_0 = A^Ty.
# $$

# %%
import numpy as np
import scipy.stats as st
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę wykres funkcji w kształcie
#
# $
# f(x)=x^2
# $
#
# na odcinku $[0,3]$ i go narysować.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: (x**2)
x_tr = np.linspace(0., 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)=x^2$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = np.array([.2, .5, .8, .9, 1.3, 1.7, 2.1, 2.7])
y = f(x) + np.random.randn(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
# We create the model.
lr = lm.LinearRegression()
# We train the model on our training dataset.
lr.fit(x[:, np.newaxis], y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [2.57535425]
# -0.6291291880673477

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr = lambda x: lr.coef_ * x +lr.intercept_

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Teraz możemy wykonać predykcję dla punktu
# $$
# x_0 = 1.5
# $$

# %%
point = np.array([1.5])
y_point = lr.predict(point[:, np.newaxis])

# %%
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.plot(point, y_point, 'or', ms=10);
plt.show()

# %% [markdown]
# Możemy wypisać miarę dopasowania $R^2$. Narazie nie wnikamy w to co ona oznacza.

# %%
from sklearn.metrics import r2_score
print(lr.score(x[:, np.newaxis], y))
print(r2_score(lr.predict(x[:, np.newaxis]), y))
# Out:
# 0.6873365980265649
# 0.5451087533078648

# %% [markdown]
# # Zadanie 1
# Stwórz macierz postaci:
# $$
# A=\begin{bmatrix}
# x_1 & 1\\
# \ddots & \ddots\\
# x_n & 1\\
# \end{bmatrix}
# $$
#
# i rozwiąż równanie
#
# $$
# A^TA x = A^Ty.
# $$
#
# gdzie (x,y) to nasz zbiór treningowy.
#
# Użyj funkcji <tt>linalg.solve</tt>.

# %%
deg=1
xx=np.vander(x, deg + 1)
xx
# Out:
# array([[0.2, 1. ],
#        [0.5, 1. ],
#        [0.8, 1. ],
#        [0.9, 1. ],
#        [1.3, 1. ],
#        [1.7, 1. ],
#        [2.1, 1. ],
#        [2.7, 1. ]])

# %%
x = np.array([.2, .5])
a = xx[:2, :]
b = f_lr(x)
print(x)
print(a)
print(b)
np.linalg.solve(a,b)
# Out:
# [0.2 0.5]
# [[0.2 1. ]
#  [0.5 1. ]]
# [-0.11405834  0.65854794]
# array([ 2.57535425, -0.62912919])

# %% [markdown]
# # Zadanie 2
# Zapoznaj się z funkcją <tt>optimize.fmin_cg</tt>
# https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.optimize.fmin_cg.html
# i znajdż minum funkcji
#
# $$
# f(x,y) = (x+1)^2+y^2
# $$

# %%
from scipy import optimize
def f(var):
    x,y = var
    return (x+1)**2+y**2
def grad_f(var):
    x,y = var
    grad_x = 2*(x+1)
    grad_y = 2*y
    return np.asarray((grad_x, grad_y))
x0 = np.asarray((0,0))
min_point = optimize.fmin_cg(f,x0,fprime=grad_f)
min = f(min_point)
print(min_point)
print(min)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
#          Gradient evaluations: 3
# [-1.  0.]
# 0.0

# %% [markdown]
# # Zadanie 3
# Zdafiniuj funkcję opisującą błąd kwadratowy:
#
# $$
# \mathrm{compute\_error}(a,b;(x,y)) =  \sum_{i=1}^{n} ( y_i - (ax_i+b) )^2.
# $$

# %%
def compute_error(var, *args):
    x,y = var
    a,b = args
    return y-(a*x+b)**2
var = np.array([[1,1,1],[1,1,1]])
print(compute_error(var, 1,1))
# Out:
# [-3 -3 -3]

# %% [markdown]
# # Zadanie 4
# Zminimalizuj funkcją $\mathrm{compute\_error}$ po parametrach $a,b$ (numerycznie).
#
# Czy wyniki są podobne do wyników z poprzednich zadań?

# %%
def min_compute_error(var, *args):
    x,y = var
    a,b = args
    x0 = (np.dot(x,y)-b*sum(x))/np.dot(x,x)
    y0 = (sum(y)-a*sum(x))/len(x)
    return np.array((x0,y0))
x = np.array([.2, .5, .8, .9, 1.3, 1.7, 2.1, 2.7])
y =
print(min_compute_error(var,1,1))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8004\2876566251.py in <module>
#       5     y0 = (sum(y)-a*sum(x))/len(x)
#       6     return np.array((x0,y0))
# ----> 7 print(min_compute_error(var,1,1))
#
# ~\AppData\Local\Temp\ipykernel_8004\2876566251.py in min_compute_error(var, *args)
#       2     x,y = var
#       3     a,b = args
# ----> 4     x0 = (np.dot(x,y)-b*sum(x))/np.dot(x,x)
#       5     y0 = (sum(y)-a*sum(x))/len(x)
#       6     return np.array((x0,y0))
#
# ~\AppData\Local\Temp\ipykernel_8004\2876566251.py in min_compute_error(var, *args)
#       2     x,y = var
#       3     a,b = args
# ----> 4     x0 = (np.dot(x,y)-b*sum(x))/np.dot(x,x)
#       5     y0 = (sum(y)-a*sum(x))/len(x)
#       6     return np.array((x0,y0))
#
# _pydevd_bundle\pydevd_cython_win32_39_64.pyx in _pydevd_bundle.pydevd_cython_win32_39_64.SafeCallWrapper.__call__()
#
# _pydevd_bundle\pydevd_cython_win32_39_64.pyx in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle\pydevd_cython_win32_39_64.pyx in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle\pydevd_cython_win32_39_64.pyx in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.trace_dispatch()
#
# C:\Program Files\JetBrains\PyCharm 2022.3.3\plugins\python\helpers-pro\jupyter_debug\pydev_jupyter_plugin.py in stop(plugin, pydb, frame, event, args, stop_info, arg, step_cmd)
#     167         frame = suspend_jupyter(main_debugger, thread, frame, step_cmd)
#     168         if frame:
# --> 169             main_debugger.do_wait_suspend(thread, frame, event, arg)
#     170             return True
#     171     return False
#
# C:\Program Files\JetBrains\PyCharm 2022.3.3\plugins\python\helpers\pydev\pydevd.py in do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1158
#    1159         with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1160             self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#    1161
#    1162     def _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread):
#
# C:\Program Files\JetBrains\PyCharm 2022.3.3\plugins\python\helpers\pydev\pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1173
#    1174                 self.process_internal_commands()
# -> 1175                 time.sleep(0.01)
#    1176
#    1177         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:

# %% [markdown]
# # Zadanie 5
# Zdafiniuj funkcję opisującą błąd kwadratowy:
#
# $$
# \mathrm{compute\_error\_1}(a,b;(x,y)) =  \sum_{i=1}^{n} |y_i - (ax_i+b)|.
# $$

# %%
def compute_error_1(var, *args):
    x,y = var
    a,b = args
    return sum([abs(yi-(a*xi+b)) for xi, yi in zip(x, y)])
compute_error_1(((2,2),(1,1)), 1,1)
# Out:
# 4

# %% [markdown]
# # Zadanie 6
# Zminimalizuj funkcją $\mathrm{compute\_error\_1}$ po parametrach $a,b$ (numerycznie).
#
# Czy wyniki są podobne do wyników z poprzednich zadań?

# %%
compute_error_1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8004\1447945248.py in <module>
# ----> 1 print(optimize.minimize(compute_error_1,np.array((0,0)),args=(1,1)))
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     692         res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     693     elif meth == 'bfgs':
# --> 694         res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     695     elif meth == 'newton-cg':
#     696         res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, **unknown_options)
#    1281         maxiter = len(x0) * 200
#    1282
# -> 1283     sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1284                                   finite_diff_rel_step=finite_diff_rel_step)
#    1285
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     261     # ScalarFunction caches. Reuse of fun(x) during grad
#     262     # calculation reduces overall function evaluations.
# --> 263     sf = ScalarFunction(fun, x0, args, grad, hess,
#     264                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     265
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     156
#     157         self._update_fun_impl = update_fun
# --> 158         self._update_fun()
#     159
#     160         # Gradient evaluation
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_fun(self)
#     249     def _update_fun(self):
#     250         if not self.f_updated:
# --> 251             self._update_fun_impl()
#     252             self.f_updated = True
#     253
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_fun()
#     153
#     154         def update_fun():
# --> 155             self.f = fun_wrapped(self.x)
#     156
#     157         self._update_fun_impl = update_fun
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#     135             # Overwriting results in undefined behaviour because
#     136             # fun(self.x) will change self.x, with the two no longer linked.
# --> 137             fx = fun(np.copy(x), *args)
#     138             # Make sure the function returns a true scalar
#     139             if not np.isscalar(fx):
#
# ~\AppData\Local\Temp\ipykernel_8004\84148448.py in compute_error_1(var, *args)
#       2     x,y = var
#       3     a,b = args
# ----> 4     return sum([abs(yi-(a*xi+b)) for xi, yi in zip(x, y)])
#       5 compute_error_1(((2,2),(1,1)), 1,1)
#
# TypeError: 'numpy.float64' object is not iterable

# %% [markdown]
# # Zadanie 7
# Wykonaj dwie powyższe regresję na danych z wartością odstającą.

# %%
f = lambda x: (x)
x_tr = np.linspace(0., 3, 200)
y_tr = f(x_tr)
x = np.array([.2, .5, .8, .9, 1.3, 1.7, 2.1, 2.7])
y = f(x) + np.random.randn(len(x))/5
y[1]=y[1]+10
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,12])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %%
points = np.column_stack((x,y))
