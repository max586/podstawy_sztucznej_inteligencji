# %% [markdown]
# # 2-wymiarowy rozkład Normalny

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as rnd
import scipy.stats as stats
from scipy.stats import multivariate_normal

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę z rozkładu Normalnego
# $$
# m = [0,0]
# $$
#
# oraz
#
# $$
# \Sigma = [[4.40, -2.75], [-2.75,  5.50]]
# $$

# %%
mean1 = np.array([0, 0])
cov1 = np.array([[4.40, -2.75], [-2.75,  5.50]])
X1_rv=multivariate_normal(mean1, cov1)
X = X1_rv.rvs(1000)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(X[:, 0], X[:, 1])
ax.set_xlim([-10,10])
ax.set_ylim([-10,10])
plt.show()

# %% [markdown]
# # Zadanie
# Proszę policzyć średnią oraz macierz kowariancji próbki.

# %%
means = X.mean(axis=0)
cov = np.cov(X.T)
print(means, cov)
# Out:
# [ 0.02437137 -0.04258133] [[ 4.28969537 -2.89819557]
#  [-2.89819557  6.13395465]]

# %%
X2_rv=multivariate_normal(means, cov)

# %%
points = X2_rv.rvs(1000)

x = points[:, 0]
y = points[:, 1]
plt.scatter(x,y)

print(x)
print(y)

x0, y0 = np.mgrid[-3:3:.01, -3:3:.01]
pos = np.dstack((x0, y0))
z = X2_rv.pdf(pos)
plt.contour(x0,y0,z)
plt.show()
# Out:
# [-4.32394863e-01  2.39851515e-01 -1.25194211e+00 -1.05707307e+00
#   1.85712225e-01 -1.64001826e+00  1.16641321e+00  1.82707335e+00
#   2.29357609e+00 -4.11229880e-01 -2.04935866e+00  7.55684035e-01
#   3.94058814e+00 -3.59849366e-01  9.55971542e-02  3.41446624e+00
#  -2.29624060e+00  2.08949750e+00 -3.93113196e+00  9.13783664e-01
#  -2.84936005e+00 -1.90510722e-01 -1.31951556e+00 -5.56882299e-01
#   1.35744078e+00 -3.34987810e+00  1.87874757e+00  1.44867002e+00
#  -3.03779462e-01 -7.72866202e-01  1.96430946e+00  8.09918702e-01
#   2.14724510e+00  1.39538909e-01  4.21361941e-01  9.34050107e-01
#   2.97751023e-01 -2.42081493e+00 -2.23637081e+00  2.99796290e+00
#  -2.30031525e+00  2.41527891e+00  1.19307629e+00  1.07265589e+00
#   4.26244996e-01  1.76243402e-01 -1.38517354e+00  1.95240795e+00
#  -3.21546942e-01  3.58447481e+00 -2.28093446e+00  2.31316132e+00
#   1.69482250e+00  1.66965822e-01  3.72632424e+00  8.04433273e-01
# ...

# %% [markdown]
# # Zadanie
# Policz wektory i wartości własne macierzy kowariancji. Narysuj na jednym wykresie
#
# - próbkę
# - poozimice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
plt.scatter(x,y)
x0, y0 = np.mgrid[-3:3:.01, -3:3:.01]
pos = np.dstack((x0, y0))
z = X2_rv.pdf(pos)
plt.contour(x0,y0,z)
eig_val, eig_vec = np.linalg.eig(cov)
print('eigenvalues = ',eig_val)
print('eigenvectors = ',eig_vec)
for vec in eig_vec:
    plt.quiver(0,0,vec[0], vec[1], angles='xy', scale_units='xy', scale=1)
plt.show()
# Out:
# eigenvalues =  [2.17046665 8.25318337]
# eigenvectors =  [[-0.8072164   0.59025561]
#  [-0.59025561 -0.8072164 ]]

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę na kwadracie $[0,1] \times [0,1]$.
# Następnie proszę policzyć średnią oraz macierz kowariancji próbki.
#
# Narysuj na jednym wykresie
#
# - próbkę
# - poziomice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
# mean2 = np.array([0, 0])
# cov2 = np.array([[1,1], [1,2]])
# X3_rv=multivariate_normal(mean2, cov2)
# X2 = X3_rv.rvs(1000)
# print(X2)
x = [np.random.random() for _ in range(1000)]
y = [np.random.random() for _ in range(1000)]
X2 = np.column_stack((x,y))
print(X2)
means2 = X2.mean(axis=0)
covs2 = np.cov(X2.T)
print('mean = ',means2)
print('cov = ', covs2)
eig_val2, eig_vec2 = np.linalg.eig(covs2)
print('eigenvalues = ',eig_val2)
print('eigenvectors = ',eig_vec2)

X4_rv = multivariate_normal(means2, covs2)
points2 = X4_rv.rvs(1000)

x2 = points2[:, 0]
y2 = points2[:, 1]
plt.scatter(x2, y2)

x02, y02 = np.mgrid[-1:1:.01, -1:1:.01]
pos2 = np.dstack((x02, y02))
z2 = X4_rv.pdf(pos2)
plt.contour(x02, y02, z2)
for vec in eig_vec2:
    plt.quiver(0,0,vec[0], vec[1], angles='xy', scale_units='xy', scale=1)
plt.show()
# Out:
# [[0.32958006 0.09937371]
#  [0.41833119 0.10192815]
#  [0.67741468 0.9497813 ]
#  ...
#  [0.98654734 0.42042908]
#  [0.81581266 0.71905285]
#  [0.48256515 0.15620915]]
# mean =  [0.4966116  0.51898604]
# cov =  [[ 0.08551644 -0.00226541]
#  [-0.00226541  0.08547585]]
# eigenvalues =  [0.08776164 0.08323065]
# eigenvectors =  [[ 0.71026767  0.7039317 ]
#  [-0.7039317   0.71026767]]

# %%
x = np.linspace(-0.5,1.5,500)
y = np.linspace(-0.5,1.5,500)
X, Y = np.meshgrid(x,y)

pr = np.random.random((1000, 2))
mean = pr.mean(axis=0)
poz = multivariate_normal(mean, np.cov(pr.T))
print('mean=',mean)
w,v=np.linalg.eig(np.cov(pr.T))

origin = np.array([mean,mean])
pos = np.dstack((X,Y))
plt.scatter(pr[:,0], pr[:,1])
plt.contour(X, Y, poz.pdf(pos), colors='red')
plt.quiver(*origin, v[:,0], v[:,1],scale_units='xy', scale=1)
plt.show()
# Out:
# mean= [0.51751631 0.4997845 ]
